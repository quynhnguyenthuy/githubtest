# %%
#import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_25548\1820987448.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
return_code = pd.read_excel(r"C:\Users\admin\Downloads\dvcnt.xlsx", sheet_name="Sheet2")

# %%
return_code
# Out:
#                         return_code   volume    percent
# 0            Successfully completed  9722776  95.380563
# 1                   Chain not found   274598   2.693810
# 2  Reconcile error / Auth Not found   179945   1.765263
# 3                           Others     16347   0.160364

# %%
merchant_loi = pd.read_excel(r"C:\Users\admin\Downloads\dvcnt.xlsx", sheet_name="Sheet3")

# %%
all_merchant = pd.read_excel(r"C:\Users\admin\Downloads\dvcnt.xlsx", sheet_name="MC")

# %%
volume_merchant = pd.read_excel(r"C:\Users\admin\Downloads\dvcnt.xlsx", sheet_name="Sheet4")

# %%
volume_merchant
# Out:
#      month  volume
# 0   202201       6
# 1   202205       9
# 2   202207       1
# 3   202210      25
# 4   202211      17
# 5   202212      33
# 6   202301      34
# 7   202302      19
# 8   202303       6
# 9   202304       3
# 10  202305     825
# 11  202306     218
# 12  202307      54
# 13  202308     192
# 14  202309     301
# 15  202310     522
# 16  202311     401
# 17  202312     416

# %%
# Create a line plot with markers and color
sns.lineplot(data=volume_merchant, x="month", y="volume", marker="o", color="g")

# Show the plot
plt.show()S

# %%
all_merchant
# Out:
#               trans_details  all_volume  volume_loi    percent
# 0          TAP HOA LIEN LUA          99        87.0  87.878788
# 1    CONG TY TNHH SONPHAT99         142       121.0  85.211268
# 2       CONG TY DAI BAO TIN         190       160.0  84.210526
# 3       CHTL THU HUONG MART         137       113.0  82.481752
# 4          TAP HOA ANH HIEN         153       126.0  82.352941
# ..                      ...         ...         ...        ...
# 313            KARAMERCHANT           2         NaN   0.000000
# 314            MPGS PREMIUM           2         NaN   0.000000
# 315        MEGAPAY*GOSTREAM          75         NaN   0.000000
# 316             FRIDAY HAIR          95         NaN   0.000000
# 317                  Under2           8         NaN   0.000000
#
# [318 rows x 4 columns]

# %%
merchant_loi
# Out:
#              trans_details  all_volume  volume_loi    percent
# 0         TAP HOA LIEN LUA          99          87  87.878788
# 1   CONG TY TNHH SONPHAT99         142         121  85.211268
# 2      CONG TY DAI BAO TIN         190         160  84.210526
# 3      CHTL THU HUONG MART         137         113  82.481752
# 4         TAP HOA ANH HIEN         153         126  82.352941
# 5          DOCTOR SKIN SPA         148         121  81.756757
# 6            CONG TY SO DO         805         657  81.614907
# 7        TAP HOA TRANG HUY         149         121  81.208054
# 8        TAP HOA NHAM VIEN         354         284  80.225989
# 9      HKD DOCTOR SKIN SPA         121          96  79.338843
# 10       BINH YEN BIRDNEST         174         136  78.160920
# 11           DUY TUNG MART         123          96  78.048780
# 12            GO TUE TUYEN          53          41  77.358491
# 13      HOANG LAN MINIMART         125          96  76.800000
# ...

# %%
sns.boxplot(
    data=merchant_loi,
    y="percent",
    showmeans=True,  # Show mean as well
    palette=["#ED7D31"],
    linewidth=1.5,  # Thicker lines
    fliersize=4,  # Smaller outliers

)



# Customize plot
#plt.title("Quantile Box Plot of Column1")
plt.xticks(rotation=45)
plt.grid(False)
#plt.legend(title="Quantiles", title_fontsize=12, frameon=False, loc='below')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4004\2716944444.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
all_merchant["percent"].describe()
# Out:
# count    318.000000
# mean      11.256893
# std       21.734049
# min        0.000000
# 25%        0.148995
# 50%        1.987515
# 75%        7.156200
# max       87.878788
# Name: percent, dtype: float64

# %%
all_merchant["percent"].quantile(0.91)
# Out:
# 53.33928571428577

# %%
merchant_loi["percent"].describe()
# Out:
# count    30.000000
# mean     72.420364
# std      10.220884
# min      52.500000
# 25%      66.341991
# 50%      74.398361
# 75%      80.962537
# max      87.878788
# Name: percent, dtype: float64

# %%
# Create the box plot
ax = sns.boxplot(data=merchant_loi, y="percent", palette='Blues')

# Calculate and add the median, Q1, and Q3
quantiles = merchant_loi['percent'].quantile([0.25, 0.5, 0.75])
ax.scatter(0, quantiles[0.25], color='red', zorder=5)  # Q1
ax.scatter(0, quantiles[0.5], color='red', zorder=5)   # Median
ax.scatter(0, quantiles[0.75], color='red', zorder=5)  # Q3

# Show the plot
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4004\1629316565.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
